# %%
#Django project
1. create virtual environment

2. django-admin startproject store_project

3.cd store project

4.python manage.py startapp core

5. pip install djangorestframework

6.pip install psycopg2-binary

7. add core and rest_framework in installed apps(settings.py)

8. add database in settings.py like host, name, passwpord

9. now code in models.ov

10. then migrate 2 commands

11.seralizer

12.views.py

13.urls.py

14. runserver

# %%
#Application
Microsoft Windows [Version 10.0.26200.7623]
(c) Microsoft Corporation. All rights reserved.

C:\Users\muska\Downloads\Django project>python -m venv env

C:\Users\muska\Downloads\Django project>env\Scripts\activate

(env) C:\Users\muska\Downloads\Django project>pip install django
Collecting django
  Downloading django-5.2.11-py3-none-any.whl (8.3 MB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 408.0 kB/s eta 0:00:00
Collecting tzdata
  Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.5/348.5 kB 349.1 kB/s eta 0:00:00
Collecting sqlparse>=0.3.1
  Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 763.8 kB/s eta 0:00:00
Collecting asgiref>=3.8.1
  Downloading asgiref-3.11.1-py3-none-any.whl (24 kB)
Collecting typing_extensions>=4
  Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
Installing collected packages: tzdata, typing_extensions, sqlparse, asgiref, django
Successfully installed asgiref-3.11.1 django-5.2.11 sqlparse-0.5.5 typing_extensions-4.15.0 tzdata-2025.3

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\Django project>django-admin startproject store_project

(env) C:\Users\muska\Downloads\Django project>cd store_project

(env) C:\Users\muska\Downloads\Django project\store_project>python manage.py startapp core

(env) C:\Users\muska\Downloads\Django project\store_project>pip install psycopg2-binary
Collecting psycopg2-binary
  Downloading psycopg2_binary-2.9.11-cp310-cp310-win_amd64.whl (2.7 MB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 238.3 kB/s eta 0:00:00
Installing collected packages: psycopg2-binary
Successfully installed psycopg2-binary-2.9.11

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\Django project\store_project>pip install djangorestframework
WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:997)'))': /simple/djangorestframework/
Collecting djangorestframework
  Downloading djangorestframework-3.16.1-py3-none-any.whl (1.1 MB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 778.3 kB/s eta 0:00:00
Requirement already satisfied: django>=4.2 in c:\users\muska\downloads\django project\env\lib\site-packages (from djangorestframework) (5.2.11)
Requirement already satisfied: sqlparse>=0.3.1 in c:\users\muska\downloads\django project\env\lib\site-packages (from django>=4.2->djangorestframework) (0.5.5)
Requirement already satisfied: asgiref>=3.8.1 in c:\users\muska\downloads\django project\env\lib\site-packages (from django>=4.2->djangorestframework) (3.11.1)
Requirement already satisfied: tzdata in c:\users\muska\downloads\django project\env\lib\site-packages (from django>=4.2->djangorestframework) (2025.3)
Requirement already satisfied: typing_extensions>=4 in c:\users\muska\downloads\django project\env\lib\site-packages (from asgiref>=3.8.1->django>=4.2->djangorestframework) (4.15.0)
Installing collected packages: djangorestframework
Successfully installed djangorestframework-3.16.1

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\Django project\store_project>psql -U postgres
Password for user postgres:

psql (18.1)
WARNING: Console code page (437) differs from Windows code page (1252)
         8-bit characters might not work correctly. See psql reference
         page "Notes for Windows users" for details.
Type "help" for help.

postgres=# create database new
postgres-# CREATE DATABASE store_db;
ERROR:  syntax error at or near "CREATE"
LINE 2: CREATE DATABASE store_db;
        ^
postgres=# create database store_db;
CREATE DATABASE
postgres=# \q

  (env) C:\Users\muska\Downloads\Django project\store_project>python manage.py makemigrations
Migrations for 'core':
  core\migrations\0001_initial.py
    + Create model Product

(env) C:\Users\muska\Downloads\Django project\store_project>python manage.py migrate
Operations to perform:
  Apply all migrations: admin, auth, contenttypes, core, sessions
Running migrations:
  Applying contenttypes.0001_initial... OK
  Applying auth.0001_initial... OK
  Applying admin.0001_initial... OK
  Applying admin.0002_logentry_remove_auto_add... OK
  Applying admin.0003_logentry_add_action_flag_choices... OK
  Applying contenttypes.0002_remove_content_type_name... OK
  Applying auth.0002_alter_permission_name_max_length... OK
  Applying auth.0003_alter_user_email_max_length... OK
  Applying auth.0004_alter_user_username_opts... OK
  Applying auth.0005_alter_user_last_login_null... OK
  Applying auth.0006_require_contenttypes_0002... OK
  Applying auth.0007_alter_validators_add_error_messages... OK
  Applying auth.0008_alter_user_username_max_length... OK
  Applying auth.0009_alter_user_last_name_max_length... OK
  Applying auth.0010_alter_group_name_max_length... OK
  Applying auth.0011_update_proxy_permissions... OK
  Applying auth.0012_alter_user_first_name_max_length... OK
  Applying core.0001_initial... OK
  Applying sessions.0001_initial... OK

(env) C:\Users\muska\Downloads\Django project\store_project>python manage.py runserver 7000
Watching for file changes with StatReloader
Performing system checks...

System check identified no issues (0 silenced).
February 16, 2026 - 15:24:40
Django version 5.2.11, using settings 'store_project.settings'
Starting development server at http://127.0.0.1:7000/
Quit the server with CTRL-BREAK.

WARNING: This is a development server. Do not use it in a production setting. Use a production WSGI or ASGI server instead.
For more information on production servers see: https://docs.djangoproject.com/en/5.2/howto/deployment/
Not Found: /
[16/Feb/2026 15:24:49] "GET / HTTP/1.1" 404 2316
[16/Feb/2026 15:24:55] "GET /products/ HTTP/1.1" 200 5140
[16/Feb/2026 15:24:56] "GET /static/rest_framework/css/prettify.css HTTP/1.1" 200 817
[16/Feb/2026 15:24:56] "GET /static/rest_framework/css/bootstrap.min.css HTTP/1.1" 200 121457
[16/Feb/2026 15:24:56] "GET /static/rest_framework/css/bootstrap-tweaks.css HTTP/1.1" 200 3426
[16/Feb/2026 15:24:56] "GET /static/rest_framework/css/default.css HTTP/1.1" 200 1152
[16/Feb/2026 15:24:56] "GET /static/rest_framework/js/csrf.js HTTP/1.1" 200 1793
[16/Feb/2026 15:24:56] "GET /static/rest_framework/js/ajax-form.js HTTP/1.1" 200 3796
[16/Feb/2026 15:24:56] "GET /static/rest_framework/js/load-ajax-form.js HTTP/1.1" 200 59
[16/Feb/2026 15:24:56] "GET /static/rest_framework/js/default.js HTTP/1.1" 200 1268
[16/Feb/2026 15:24:56] "GET /static/rest_framework/js/prettify-min.js HTTP/1.1" 200 13632
[16/Feb/2026 15:24:56] "GET /static/rest_framework/js/bootstrap.min.js HTTP/1.1" 200 39680
[16/Feb/2026 15:24:56] "GET /static/rest_framework/img/grid.png HTTP/1.1" 200 1458
[16/Feb/2026 15:24:56] "GET /static/rest_framework/js/jquery-3.7.1.min.js HTTP/1.1" 200 87533
Not Found: /favicon.ico
[16/Feb/2026 15:24:56] "GET /favicon.ico HTTP/1.1" 404 2367
