# %%
pagination-->Divides large data into smaller chunks (pages).
Why we use it:
To avoid loading all records at once (better performance).

*filter:Selects specific data based on conditions.

Why we use it:
To get only required records.

**order:
Sorts the data (ascending or descending).

Why we use it:
To arrange data in a particular order.

now adding the pagination code in settings.py
REST_FRAMEWORK = {
    'DEFAULT_PERMISSION_CLASS':
        'rest_framework.pagination.PageNumberPagination',

    'PAGE_SIZE': 2,
}

now in views.py change the get part in function of get part (just remove the serailizer part in first if statement and add pagination code)

also add this importing part of pagination
from rest_framework.pagination import PageNumberPagination


if request.method == 'GET':
        students = Student.objects.all()
        paginator = PageNumberPagination()
        paginator.page_size = 2  #same as settings.py

        paginated_students = paginator.paginate_queryset(students, request)
        serializer = StudentSerailizer(paginated_students, many=True)

        return paginator.get_paginated_response(serializer.data)

now for filter need to install so write the command pip install django-filter
now run the server
now edit the settings.py
in installed apps add 'django_filters',
and in rest_frameworks add
 'DEFAULT_FILTER_BACKENDS': [
        'django_filters.rest_framework.DjangoFilterBackend',
    ],

next in views add these in first if statement

age = request.query_params.get('age')
        name = request.query_params.get('name')
        if age :
            students = students.filter(age=age)
        if name:
            students = students.filter(name__icontains=name)

and also add these two lines :
ordering = request.query_params.get('ordering')
        search = request.query_params.get('search')

if ordering:
            students = students.order_by(ordering)
JWT --> json web token
to secure API
jwt-->json webtoken---->to secure api
***redis-->Remote Dictionary Server) is an in-memory key–value database
    \__  basically storing or performing operations in ram
why redis? faster processing and fetching

flow of JWT
username + password
login
token is given
token sent with every request
server check token
allow or reject

install jwt in command prompt :pip install djangorestframework-simplejwt
and next open settings.py and add these

'DEFAULT_AUTHENTICATION_CLASSES': (
        'rest_framework_simplejwt.authentication.JWTAuthentication',
        'rest_framework.authentication.SessionAuthentication',
next go to command prompt and write :
python manage.py createsuperuser
and press enter where it is showing the username
and give the email address
and set the password
the it will show the superuser is created successfully

# %%
#Application of JWT
Microsoft Windows [Version 10.0.26200.7623]
(c) Microsoft Corporation. All rights reserved.

C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>python -m venv env

C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>env\Scripts\activate

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>pip install Django
Collecting Django
  Using cached django-5.2.11-py3-none-any.whl (8.3 MB)
Collecting tzdata
  Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
Collecting asgiref>=3.8.1
  Using cached asgiref-3.11.1-py3-none-any.whl (24 kB)
Collecting sqlparse>=0.3.1
  Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
Collecting typing_extensions>=4
  Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
Installing collected packages: tzdata, typing_extensions, sqlparse, asgiref, Django
Successfully installed Django-5.2.11 asgiref-3.11.1 sqlparse-0.5.5 typing_extensions-4.15.0 tzdata-2025.3

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>pip install djangorestframework
Collecting djangorestframework
  Using cached djangorestframework-3.16.1-py3-none-any.whl (1.1 MB)
Requirement already satisfied: django>=4.2 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from djangorestframework) (5.2.11)
Requirement already satisfied: asgiref>=3.8.1 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from django>=4.2->djangorestframework) (3.11.1)
Requirement already satisfied: tzdata in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from django>=4.2->djangorestframework) (2025.3)
Requirement already satisfied: sqlparse>=0.3.1 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from django>=4.2->djangorestframework) (0.5.5)
Requirement already satisfied: typing_extensions>=4 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from asgiref>=3.8.1->django>=4.2->djangorestframework) (4.15.0)
Installing collected packages: djangorestframework
Successfully installed djangorestframework-3.16.1

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>pip install psycopg2-binary
Collecting psycopg2-binary
  Using cached psycopg2_binary-2.9.11-cp310-cp310-win_amd64.whl (2.7 MB)
Installing collected packages: psycopg2-binary
Successfully installed psycopg2-binary-2.9.11

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school\school>cd ..

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>pip install django-filter
Collecting django-filter
  Downloading django_filter-25.2-py3-none-any.whl (94 kB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 kB 762.8 kB/s eta 0:00:00
Requirement already satisfied: Django>=5.2 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from django-filter) (5.2.11)
Requirement already satisfied: sqlparse>=0.3.1 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from Django>=5.2->django-filter) (0.5.5)
Requirement already satisfied: tzdata in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from Django>=5.2->django-filter) (2025.3)
Requirement already satisfied: asgiref>=3.8.1 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from Django>=5.2->django-filter) (3.11.1)
Requirement already satisfied: typing_extensions>=4 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from asgiref>=3.8.1->Django>=5.2->django-filter) (4.15.0)
Installing collected packages: django-filter
Successfully installed django-filter-25.2

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>pip install djangorestframework-simplejwt
Collecting djangorestframework-simplejwt
  Downloading djangorestframework_simplejwt-5.5.1-py3-none-any.whl (107 kB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 696.0 kB/s eta 0:00:00
Requirement already satisfied: django>=4.2 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from djangorestframework-simplejwt) (5.2.11)
Requirement already satisfied: djangorestframework>=3.14 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from djangorestframework-simplejwt) (3.16.1)
Collecting pyjwt>=1.7.1
  Downloading pyjwt-2.11.0-py3-none-any.whl (28 kB)
Requirement already satisfied: sqlparse>=0.3.1 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from django>=4.2->djangorestframework-simplejwt) (0.5.5)
Requirement already satisfied: tzdata in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from django>=4.2->djangorestframework-simplejwt) (2025.3)
Requirement already satisfied: asgiref>=3.8.1 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from django>=4.2->djangorestframework-simplejwt) (3.11.1)
Requirement already satisfied: typing_extensions>=4 in c:\users\muska\downloads\iit phagwara (django project)\school\env\lib\site-packages (from asgiref>=3.8.1->django>=4.2->djangorestframework-simplejwt) (4.15.0)
Installing collected packages: pyjwt, djangorestframework-simplejwt
Successfully installed djangorestframework-simplejwt-5.5.1 pyjwt-2.11.0

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>python manage.py createsuperuser
Username (leave blank to use 'muska'):
Email address: muskan.dhawan2023@gmail.com
Password:
Password (again):
This password is too short. It must contain at least 8 characters.
This password is too common.
This password is entirely numeric.
Bypass password validation and create user anyway? [y/N]: y
Superuser created successfully.

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>python manage.py runserver
Watching for file changes with StatReloader
Performing system checks...

System check identified no issues (0 silenced).
February 19, 2026 - 13:30:01
Django version 5.2.11, using settings 'school.settings'
Starting development server at http://127.0.0.1:8000/
Quit the server with CTRL-BREAK.

WARNING: This is a development server. Do not use it in a production setting. Use a production WSGI or ASGI server instead.
For more information on production servers see: https://docs.djangoproject.com/en/5.2/howto/deployment/
Unauthorized: /students/
[19/Feb/2026 13:30:17] "GET /students/ HTTP/1.1" 401 5058
Unauthorized: /students/
[19/Feb/2026 13:30:22] "GET /students/ HTTP/1.1" 401 5058
[19/Feb/2026 13:30:23] "GET /static/rest_framework/css/bootstrap-tweaks.css HTTP/1.1" 200 3426
[19/Feb/2026 13:30:23] "GET /static/rest_framework/css/default.css HTTP/1.1" 200 1152
[19/Feb/2026 13:30:23] "GET /static/rest_framework/css/prettify.css HTTP/1.1" 200 817
[19/Feb/2026 13:30:23] "GET /static/rest_framework/css/bootstrap.min.css HTTP/1.1" 200 121457
[19/Feb/2026 13:30:23] "GET /static/rest_framework/js/csrf.js HTTP/1.1" 200 1793
[19/Feb/2026 13:30:23] "GET /static/rest_framework/js/ajax-form.js HTTP/1.1" 200 3796
[19/Feb/2026 13:30:23] "GET /static/rest_framework/img/grid.png HTTP/1.1" 200 1458
[19/Feb/2026 13:30:23] "GET /static/rest_framework/js/load-ajax-form.js HTTP/1.1" 200 59
[19/Feb/2026 13:30:23] "GET /static/rest_framework/js/default.js HTTP/1.1" 200 1268
[19/Feb/2026 13:30:23] "GET /static/rest_framework/js/prettify-min.js HTTP/1.1" 200 13632
[19/Feb/2026 13:30:23] "GET /static/rest_framework/js/bootstrap.min.js HTTP/1.1" 200 39680
[19/Feb/2026 13:30:23] "GET /static/rest_framework/js/jquery-3.7.1.min.js HTTP/1.1" 200 87533
Not Found: /favicon.ico
[19/Feb/2026 13:30:23] "GET /favicon.ico HTTP/1.1" 404 2841
