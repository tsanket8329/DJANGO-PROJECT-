# %%
#Django Project - IIT phagwara
#Url.py
"""
URL configuration for school project.

The `urlpatterns` list routes URLs to views. For more information please see:
    https://docs.djangoproject.com/en/5.2/topics/http/urls/
Examples:
Function views
    1. Add an import:  from my_app import views
    2. Add a URL to urlpatterns:  path('', views.home, name='home')
Class-based views
    1. Add an import:  from other_app.views import Home
    2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
Including another URLconf
    1. Import the include() function: from django.urls import include, path
    2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
"""
from django.contrib import admin
from django.urls import path
from students.views import student_list
from students.views import student_detail

urlpatterns = [
    path('admin/', admin.site.urls),
    path('students/', student_list),
    path('students/<int:id>/', student_detail),
]
]
#Settings.py
"""
Django settings for school project.

Generated by 'django-admin startproject' using Django 5.2.11.

For more information on this file, see
https://docs.djangoproject.com/en/5.2/topics/settings/

For the full list of settings and their values, see
https://docs.djangoproject.com/en/5.2/ref/settings/
"""

from pathlib import Path

# Build paths inside the project like this: BASE_DIR / 'subdir'.
BASE_DIR = Path(__file__).resolve().parent.parent


# Quick-start development settings - unsuitable for production
# See https://docs.djangoproject.com/en/5.2/howto/deployment/checklist/

# SECURITY WARNING: keep the secret key used in production secret!
SECRET_KEY = 'django-insecure-s2x8$_bpuos*w68ekito)5x&_os)lhs^o4l(utdd!u+#_#)n!d'

# SECURITY WARNING: don't run with debug turned on in production!
DEBUG = True

ALLOWED_HOSTS = []


# Application definition

INSTALLED_APPS = [
    'django.contrib.admin',
    'django.contrib.auth',
    'django.contrib.contenttypes',
    'django.contrib.sessions',
    'django.contrib.messages',
    'django.contrib.staticfiles',
    'students',
    'rest_framework',
]

MIDDLEWARE = [
    'django.middleware.security.SecurityMiddleware',
    'django.contrib.sessions.middleware.SessionMiddleware',
    'django.middleware.common.CommonMiddleware',
    'django.middleware.csrf.CsrfViewMiddleware',
    'django.contrib.auth.middleware.AuthenticationMiddleware',
    'django.contrib.messages.middleware.MessageMiddleware',
    'django.middleware.clickjacking.XFrameOptionsMiddleware',
]

ROOT_URLCONF = 'school.urls'

TEMPLATES = [
    {
        'BACKEND': 'django.template.backends.django.DjangoTemplates',
        'DIRS': [],
        'APP_DIRS': True,
        'OPTIONS': {
            'context_processors': [
                'django.template.context_processors.request',
                'django.contrib.auth.context_processors.auth',
                'django.contrib.messages.context_processors.messages',
            ],
        },
    },
]

WSGI_APPLICATION = 'school.wsgi.application'


# Database
# https://docs.djangoproject.com/en/5.2/ref/settings/#databases

DATABASES = {
    'default': {
        'ENGINE': 'django.db.backends.postgresql',
        'NAME': 'attendance',
        'USER': 'postgres',
        'PASSWORD': '123',
        'HOST': 'localhost',
        'PORT': '5432',

    }
}


# Password validation
# https://docs.djangoproject.com/en/5.2/ref/settings/#auth-password-validators

AUTH_PASSWORD_VALIDATORS = [
    {
        'NAME': 'django.contrib.auth.password_validation.UserAttributeSimilarityValidator',
    },
    {
        'NAME': 'django.contrib.auth.password_validation.MinimumLengthValidator',
    },
    {
        'NAME': 'django.contrib.auth.password_validation.CommonPasswordValidator',
    },
    {
        'NAME': 'django.contrib.auth.password_validation.NumericPasswordValidator',
    },
]


# Internationalization
# https://docs.djangoproject.com/en/5.2/topics/i18n/

LANGUAGE_CODE = 'en-us'

TIME_ZONE = 'UTC'

USE_I18N = True

USE_TZ = True


# Static files (CSS, JavaScript, Images)
# https://docs.djangoproject.com/en/5.2/howto/static-files/

STATIC_URL = 'static/'

# Default primary key field type
# https://docs.djangoproject.com/en/5.2/ref/settings/#default-auto-field

DEFAULT_AUTO_FIELD = 'django.db.models.BigAutoField'
#Views.py
from django.shortcuts import render
from rest_framework.decorators import api_view
from rest_framework.response import Response
from .models import Student
from .serializers import StudentSerializer
@api_view(['GET','POST'])
def student_list(request):
    if request.method == 'GET':
        students = Student.objects.all()
        serializer = StudentSerializer(students, many=True)
        return Response(serializer.data)
    if request.method == 'POST':
        serializer = StudentSerializer(data=request.data)
        if serializer.is_valid():
            serializer.save()
            return Response(serializer.data, status=201)
        return Response(serializer.errors, status=400)
@api_view(['GET','PUT','DELETE','PATCH'])
def student_detail(request,id):
    try:
        student = Student.objects.get(id=id)
    except Student.DoesNotExist:
        return Response({'error': 'Student not found'}, status=404)
    if request.method == 'GET':
        serializer = StudentSerializer(student)
        return Response(serializer.data)
    if request.method == 'PUT':
        serializer = StudentSerializer(student, data=request.data)
        if serializer.is_valid():
            serializer.save()
            return Response(serializer.data)
        return Response(serializer.errors, status=400)
    if request.method=='DELETE':
         student.delete()
         return Response({'message':'deleted'})
    if request.method == 'PATCH':
        serializer = StudentSerializer(student,    data=request.data,partial=True)
        if serializer.is_valid():
            serializer.save()
            return Response(serializer.data)
        return Response(serializer.errors, status=400)

#Serializers.py
from rest_framework import serializers
from .models import Student
class StudentSerializer(serializers.ModelSerializer):
    class Meta:
        model=Student
        fields='__all__'
#Models.py
from django.db import models
class Student(models.Model):
    name=models.CharField(max_length=100)
    age=models.IntegerField()
    email=models.EmailField(unique=True)
    def __str__(self):
        return self.name

# %%
#Application
Microsoft Windows [Version 10.0.26200.7623]
(c) Microsoft Corporation. All rights reserved.

C:\Users\muska\Downloads\IIT Phagwara (Django project)>python -m venv env

C:\Users\muska\Downloads\IIT Phagwara (Django project)>env\Scipts\activate
The system cannot find the path specified.

C:\Users\muska\Downloads\IIT Phagwara (Django project)>env\Scripts\activate

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)>pip install django djangorestframework psycopg2-binary
Collecting django
  Using cached django-5.2.11-py3-none-any.whl (8.3 MB)
Collecting djangorestframework
  Using cached djangorestframework-3.16.1-py3-none-any.whl (1.1 MB)
Collecting psycopg2-binary
  Using cached psycopg2_binary-2.9.11-cp310-cp310-win_amd64.whl (2.7 MB)
Collecting asgiref>=3.8.1
  Using cached asgiref-3.11.1-py3-none-any.whl (24 kB)
Collecting sqlparse>=0.3.1
  Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
Collecting tzdata
  Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
Collecting typing_extensions>=4
  Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
Installing collected packages: tzdata, typing_extensions, sqlparse, psycopg2-binary, asgiref, django, djangorestframework
Successfully installed asgiref-3.11.1 django-5.2.11 djangorestframework-3.16.1 psycopg2-binary-2.9.11 sqlparse-0.5.5 typing_extensions-4.15.0 tzdata-2025.3

[notice] A new release of pip available: 22.2.2 -> 26.0.1
[notice] To update, run: python.exe -m pip install --upgrade pip

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)>django-admin startproject school

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)>cd school

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>python manage.py startapp students

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>psql -U postgres
Password for user postgres:

psql (18.1)
WARNING: Console code page (437) differs from Windows code page (1252)
         8-bit characters might not work correctly. See psql reference
         page "Notes for Windows users" for details.
Type "help" for help.

postgres=# CREATE DATABASE attendance;
CREATE DATABASE
postgres=# \q

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>python manage.py makemigrations
Migrations for 'students':
  students\migrations\0001_initial.py
    + Create model Student

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>python manage.py migrate
Operations to perform:
  Apply all migrations: admin, auth, contenttypes, sessions, students
Running migrations:
  Applying contenttypes.0001_initial... OK
  Applying auth.0001_initial... OK
  Applying admin.0001_initial... OK
  Applying admin.0002_logentry_remove_auto_add... OK
  Applying admin.0003_logentry_add_action_flag_choices... OK
  Applying contenttypes.0002_remove_content_type_name... OK
  Applying auth.0002_alter_permission_name_max_length... OK
  Applying auth.0003_alter_user_email_max_length... OK
  Applying auth.0004_alter_user_username_opts... OK
  Applying auth.0005_alter_user_last_login_null... OK
  Applying auth.0006_require_contenttypes_0002... OK
  Applying auth.0007_alter_validators_add_error_messages... OK
  Applying auth.0008_alter_user_username_max_length... OK
  Applying auth.0009_alter_user_last_name_max_length... OK
  Applying auth.0010_alter_group_name_max_length... OK
  Applying auth.0011_update_proxy_permissions... OK
  Applying auth.0012_alter_user_first_name_max_length... OK
  Applying sessions.0001_initial... OK
  Applying students.0001_initial... OK

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>python manage.py runserver
Watching for file changes with StatReloader
Performing system checks...

System check identified no issues (0 silenced).
February 18, 2026 - 10:44:01
Django version 5.2.11, using settings 'school.settings'
Starting development server at http://127.0.0.1:8000/
Quit the server with CTRL-BREAK.

WARNING: This is a development server. Do not use it in a production setting. Use a production WSGI or ASGI server instead.
For more information on production servers see: https://docs.djangoproject.com/en/5.2/howto/deployment/
Not Found: /students/
[18/Feb/2026 10:44:33] "GET /students/ HTTP/1.1" 404 2355
Not Found: /favicon.ico
[18/Feb/2026 10:44:33] "GET /favicon.ico HTTP/1.1" 404 2361
Not Found: /students/
[18/Feb/2026 10:44:44] "GET /students/ HTTP/1.1" 404 2355
Not Found: /students/
[18/Feb/2026 10:44:45] "GET /students/ HTTP/1.1" 404 2355
Not Found: /Students/
[18/Feb/2026 10:45:33] "GET /Students/ HTTP/1.1" 404 2355
Not Found: /Students/
[18/Feb/2026 10:45:36] "GET /Students/ HTTP/1.1" 404 2355
Not Found: /students/
[18/Feb/2026 10:45:44] "GET /students/ HTTP/1.1" 404 2355
Not Found: /students/
[18/Feb/2026 10:45:46] "GET /students/ HTTP/1.1" 404 2355
Not Found: /students/
[18/Feb/2026 10:47:53] "GET /students/ HTTP/1.1" 404 2355
C:\Users\muska\Downloads\IIT Phagwara (Django project)\school\school\urls.py changed, reloading.
Watching for file changes with StatReloader
Performing system checks...

System check identified no issues (0 silenced).
February 18, 2026 - 10:50:19
Django version 5.2.11, using settings 'school.settings'
Starting development server at http://127.0.0.1:8000/
Quit the server with CTRL-BREAK.

WARNING: This is a development server. Do not use it in a production setting. Use a production WSGI or ASGI server instead.
For more information on production servers see: https://docs.djangoproject.com/en/5.2/howto/deployment/

(env) C:\Users\muska\Downloads\IIT Phagwara (Django project)\school>python manage.py runserver
Watching for file changes with StatReloader
Performing system checks...

System check identified no issues (0 silenced).
February 18, 2026 - 10:50:31
Django version 5.2.11, using settings 'school.settings'
Starting development server at http://127.0.0.1:8000/
Quit the server with CTRL-BREAK.

WARNING: This is a development server. Do not use it in a production setting. Use a production WSGI or ASGI server instead.
For more information on production servers see: https://docs.djangoproject.com/en/5.2/howto/deployment/
[18/Feb/2026 10:50:51] "GET /students/ HTTP/1.1" 200 6782
[18/Feb/2026 10:50:51] "GET /static/rest_framework/css/default.css HTTP/1.1" 200 1152
[18/Feb/2026 10:50:51] "GET /static/rest_framework/css/bootstrap-tweaks.css HTTP/1.1" 200 3426
[18/Feb/2026 10:50:51] "GET /static/rest_framework/css/prettify.css HTTP/1.1" 200 817
[18/Feb/2026 10:50:52] "GET /static/rest_framework/css/bootstrap.min.css HTTP/1.1" 200 121457
[18/Feb/2026 10:50:52] "GET /static/rest_framework/js/ajax-form.js HTTP/1.1" 200 3796
[18/Feb/2026 10:50:52] "GET /static/rest_framework/js/csrf.js HTTP/1.1" 200 1793
[18/Feb/2026 10:50:52] "GET /static/rest_framework/js/default.js HTTP/1.1" 200 1268
[18/Feb/2026 10:50:52] "GET /static/rest_framework/js/bootstrap.min.js HTTP/1.1" 200 39680
[18/Feb/2026 10:50:52] "GET /static/rest_framework/js/prettify-min.js HTTP/1.1" 200 13632
[18/Feb/2026 10:50:52] "GET /static/rest_framework/js/load-ajax-form.js HTTP/1.1" 200 59
[18/Feb/2026 10:50:52] "GET /static/rest_framework/img/grid.png HTTP/1.1" 200 1458
[18/Feb/2026 10:50:52] "GET /static/rest_framework/js/jquery-3.7.1.min.js HTTP/1.1" 200 87533
[18/Feb/2026 10:59:04] "GET /students/ HTTP/1.1" 200 6782
[18/Feb/2026 10:59:04] "GET /static/rest_framework/css/bootstrap.min.css HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/css/bootstrap-tweaks.css HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/css/prettify.css HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/css/default.css HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/js/csrf.js HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/js/bootstrap.min.js HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/js/ajax-form.js HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/js/jquery-3.7.1.min.js HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/js/default.js HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/js/prettify-min.js HTTP/1.1" 304 0
[18/Feb/2026 10:59:04] "GET /static/rest_framework/js/load-ajax-form.js HTTP/1.1" 304 0
Bad Request: /students/
[18/Feb/2026 11:13:36] "POST /students/ HTTP/1.1" 400 6903
Internal Server Error: /students/
Traceback (most recent call last):
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\django\core\handlers\exception.py", line 55, in inner
    response = get_response(request)
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\django\core\handlers\base.py", line 197, in _get_response
    response = wrapped_callback(request, *callback_args, **callback_kwargs)
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\django\views\decorators\csrf.py", line 65, in _view_wrapper
    return view_func(request, *args, **kwargs)
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\django\views\generic\base.py", line 105, in view
    return self.dispatch(request, *args, **kwargs)
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\rest_framework\views.py", line 515, in dispatch
    response = self.handle_exception(exc)
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\rest_framework\views.py", line 475, in handle_exception
    self.raise_uncaught_exception(exc)
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\rest_framework\views.py", line 486, in raise_uncaught_exception
    raise exc
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\rest_framework\views.py", line 512, in dispatch
    response = handler(request, *args, **kwargs)
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\rest_framework\decorators.py", line 50, in handler
    return func(*args, **kwargs)
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\school\students\views.py", line 14, in student_list
    if serializer.is_valid():
  File "C:\Users\muska\Downloads\IIT Phagwara (Django project)\env\lib\site-packages\rest_framework\serializers.py", line 218, in is_valid
    assert hasattr(self, 'initial_data'), (
AssertionError: Cannot call `.is_valid()` as no `data=` keyword argument was passed when instantiating the serializer instance.
[18/Feb/2026 11:15:05] "POST /students/ HTTP/1.1" 500 100828
C:\Users\muska\Downloads\IIT Phagwara (Django project)\school\students\views.py changed, reloading.
Watching for file changes with StatReloader
Performing system checks...

System check identified no issues (0 silenced).
February 18, 2026 - 11:16:54
Django version 5.2.11, using settings 'school.settings'
Starting development server at http://127.0.0.1:8000/
Quit the server with CTRL-BREAK.

WARNING: This is a development server. Do not use it in a production setting. Use a production WSGI or ASGI server instead.
For more information on production servers see: https://docs.djangoproject.com/en/5.2/howto/deployment/
[18/Feb/2026 11:17:39] "GET /students/ HTTP/1.1" 200 6782
[18/Feb/2026 11:17:39] "GET /static/rest_framework/css/bootstrap.min.css HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/css/bootstrap-tweaks.css HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/css/default.css HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/css/prettify.css HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/js/csrf.js HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/js/bootstrap.min.js HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/js/ajax-form.js HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/js/jquery-3.7.1.min.js HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/js/prettify-min.js HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/js/default.js HTTP/1.1" 304 0
[18/Feb/2026 11:17:39] "GET /static/rest_framework/js/load-ajax-form.js HTTP/1.1" 304 0
[18/Feb/2026 11:19:02] "POST /students/ HTTP/1.1" 201 6991

# %%
#API
Browser ->request -> django -> urls -> views
#rest_framework
Django REST Framework is a Django-based library used to build RESTful APIs that return JSON responses and handle CRUD operations efficiently.
Get - Fetch
Post - Insert/ Create
Put - Update
Delete - Delete
Patch - Update the partial data
#JWT - JSON web token to secure API
#Reddis - Storing or performing operations in RAM
Why reddis ? Faster processing and fetching
